# %% [markdown]
# ## Carregar Informações

# %%
# importando bibliotecas
import pandas as pd

# %%
# carregando os dados
fifa = pd.read_csv('data/fifa_eda.csv', sep=',', skiprows=None)
fifa.head()

# Para carregar dados de arquivo Excel
# x1 = pd.ExcelFile(file) #Carrega o arquivo
# df = x1.parse('Sheet1') #Carrega uma aba
# Out:
#        ID       Name  Age Nationality  Overall  Potential       Club  \
# 0  158023   L. Messi   31  Argentina        94         94  FC Bar...
# 1   20801  Cristi...   33   Portugal        94         94   Juventus
# 2  190871  Neymar Jr   26     Brazil        92         93  Paris ...
# 3  193080     De Gea   27      Spain        91         93  Manche...
# 4  192985  K. De ...   27    Belgium        91         92  Manche...
#
#       Value   Wage Preferred Foot  International Reputation  Skill Moves  \
# 0  110500.0  565.0       Left            5.0                       4.0
# 1   77000.0  405.0      Right            5.0                       5.0
# 2  118500.0  290.0      Right            5.0                       5.0
# 3   72000.0  260.0      Right            4.0                       1.0
# 4  102000.0  355.0      Right            4.0                       4.0
#
#   Position  Joined Contract Valid Until    Height  Weight  Release Clause
# ...

# %%
fifa.tail(10)
# Out:
#            ID       Name  Age Nationality  Overall  Potential       Club  \
# 18197  246167  D. Hol...   18  Republ...        47         61  Cork City
# 18198  242844  J. Liv...   18    England        47         70  Burton...
# 18199  244677  M. Bal...   18     Canada        47         69  Vancou...
# 18200  231381   J. Young   18   Scotland        47         62  Swindo...
# 18201  243413   D. Walsh   18  Republ...        47         68  Waterf...
# 18202  238813  J. Lun...   19    England        47         65  Crewe ...
# 18203  243165  N. Chr...   19     Sweden        47         63  Trelle...
# 18204  241638  B. Worman   16    England        47         67  Cambri...
# 18205  246268  D. Wal...   17    England        47         66  Tranme...
# 18206  246269  G. Nugent   16    England        46         66  Tranme...
#
#        Value  Wage Preferred Foot  International Reputation  Skill Moves  \
# 18197   60.0   1.0      Right            1.0                       2.0
# ...

# %% [markdown]
# ## Informações sobre o DataSet

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
fifa.shape #Número de linas e colunas
# Out:
# (18207, 18)

# %%
print("Esse df possui %0.f linhas e %0.f colunas" % (fifa.shape[0], fifa.shape[1]))
# Out:
# Esse df possui 18207 linhas e 18 colunas

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause'],
#       dtype='object')

# %% [markdown]
# Para estabelecer uma coluna como um índice basta usar set_index
# - df.set_index('nome_da_coluna') # para uma ocluna
# - df.set_index(['nome_da_coluna1', 'nome_da_coluna2', 'nome_da_coluna3']) # para várias colunas
# - df.set_index([pd.Index][1,2,3,4,...], 'nome do indice') # para criar um índice novo do zero

# %%
# para mostrar head e tail na mesma célula
display(fifa.head(3))
display(fifa.tail(2))
# Out:
#        ID       Name  Age Nationality  Overall  Potential       Club  \
# 0  158023   L. Messi   31  Argentina        94         94  FC Bar...
# 1   20801  Cristi...   33   Portugal        94         94   Juventus
# 2  190871  Neymar Jr   26     Brazil        92         93  Paris ...
#
#       Value   Wage Preferred Foot  International Reputation  Skill Moves  \
# 0  110500.0  565.0       Left            5.0                       4.0
# 1   77000.0  405.0      Right            5.0                       5.0
# 2  118500.0  290.0      Right            5.0                       5.0
#
#   Position  Joined Contract Valid Until    Height  Weight  Release Clause
# 0       RF    2004  2021-0...            5.583333   159.0   226500.0
# 1       ST    2018  2022-0...            6.166667   183.0   127100.0
# 2       LW    2017  2022-0...            5.750000   150.0   228100.0
#            ID       Name  Age Nationality  Overall  Potential       Club  \
# ...

# %%
print(pd.get_option('max_colwidth'))

pd.set_option('max_colwidth', 10)

print(pd.get_option('max_colwidth'))
# Out:
# 10
# 10

# %%
#Formatação condicional, muda a cor dos valores abaixo de 91 nas colunas Overall e Potential
def low_values_red(value):
    color = 'red' if value < 92 else 'blak'
    return 'color: %s '%color

fifa[['Overall', 'Potential']].head(10).style.applymap(low_values_red)
# Out:
# <style type="text/css">
# #T_99062_row0_col0, #T_99062_row0_col1, #T_99062_row1_col0, #T_99062_row1_col1, #T_99062_row2_col0, #T_99062_row2_col1, #T_99062_row3_col1, #T_99062_row4_col1, #T_99062_row9_col1 {
#   color: blak;
# }
# #T_99062_row3_col0, #T_99062_row4_col0, #T_99062_row5_col0, #T_99062_row5_col1, #T_99062_row6_col0, #T_99062_row6_col1, #T_99062_row7_col0, #T_99062_row7_col1, #T_99062_row8_col0, #T_99062_row8_col1, #T_99062_row9_col0 {
#   color: red;
# }
# </style>
# <table id="T_99062">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99062_level0_col0" class="col_heading level0 col0" >Overall</th>
#       <th id="T_99062_level0_col1" class="col_heading level0 col1" >Potential</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99062_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99062_row0_col0" class="data row0 col0" >94</td>
# ...

# %%
#Formatação condicional, mostra todas as colunas mas
# muda a cor dos valores abaixo de 91 apenas nas colunas Overall e Potential
fifa.head(10).style.applymap(low_values_red, subset=['Overall', 'Potential'])
# Out:
# <style type="text/css">
# #T_2f8f2_row0_col4, #T_2f8f2_row0_col5, #T_2f8f2_row1_col4, #T_2f8f2_row1_col5, #T_2f8f2_row2_col4, #T_2f8f2_row2_col5, #T_2f8f2_row3_col5, #T_2f8f2_row4_col5, #T_2f8f2_row9_col5 {
#   color: blak;
# }
# #T_2f8f2_row3_col4, #T_2f8f2_row4_col4, #T_2f8f2_row5_col4, #T_2f8f2_row5_col5, #T_2f8f2_row6_col4, #T_2f8f2_row6_col5, #T_2f8f2_row7_col4, #T_2f8f2_row7_col5, #T_2f8f2_row8_col4, #T_2f8f2_row8_col5, #T_2f8f2_row9_col4 {
#   color: red;
# }
# </style>
# <table id="T_2f8f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f8f2_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_2f8f2_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_2f8f2_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_2f8f2_level0_col3" class="col_heading level0 col3" >Nationality</th>
#       <th id="T_2f8f2_level0_col4" class="col_heading level0 col4" >Overall</th>
# ...

# %%
def highlight_max(s):
    is_max = s == s.max() # checa esse booleano (s == is_max) depois guarda em is_max
    return ['background-color: yellow' if v else '' for v in is_max]

fifa.head(10).style.apply(highlight_max, subset=['Age', 'Overall', 'Potential', 'Value'])
# Out:
# <style type="text/css">
# #T_7e59d_row0_col4, #T_7e59d_row0_col5, #T_7e59d_row1_col2, #T_7e59d_row1_col4, #T_7e59d_row1_col5, #T_7e59d_row2_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_7e59d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e59d_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_7e59d_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_7e59d_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_7e59d_level0_col3" class="col_heading level0 col3" >Nationality</th>
#       <th id="T_7e59d_level0_col4" class="col_heading level0 col4" >Overall</th>
#       <th id="T_7e59d_level0_col5" class="col_heading level0 col5" >Potential</th>
#       <th id="T_7e59d_level0_col6" class="col_heading level0 col6" >Club</th>
#       <th id="T_7e59d_level0_col7" class="col_heading level0 col7" >Value</th>
# ...

# %%
# Utiliza as duas formatações
fifa[['Overall', 'Potential', 'Value']].head(10).style.\
    applymap(low_values_red).\
    apply(highlight_max)
# Out:
# <style type="text/css">
# #T_049ce_row0_col0, #T_049ce_row0_col1, #T_049ce_row1_col0, #T_049ce_row1_col1, #T_049ce_row2_col2 {
#   color: blak;
#   background-color: yellow;
# }
# #T_049ce_row0_col2, #T_049ce_row1_col2, #T_049ce_row2_col0, #T_049ce_row2_col1, #T_049ce_row3_col1, #T_049ce_row3_col2, #T_049ce_row4_col1, #T_049ce_row4_col2, #T_049ce_row5_col2, #T_049ce_row6_col2, #T_049ce_row7_col2, #T_049ce_row8_col2, #T_049ce_row9_col1, #T_049ce_row9_col2 {
#   color: blak;
# }
# #T_049ce_row3_col0, #T_049ce_row4_col0, #T_049ce_row5_col0, #T_049ce_row5_col1, #T_049ce_row6_col0, #T_049ce_row6_col1, #T_049ce_row7_col0, #T_049ce_row7_col1, #T_049ce_row8_col0, #T_049ce_row8_col1, #T_049ce_row9_col0 {
#   color: red;
# }
# </style>
# <table id="T_049ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_049ce_level0_col0" class="col_heading level0 col0" >Overall</th>
#       <th id="T_049ce_level0_col1" class="col_heading level0 col1" >Potential</th>
# ...

# %% [markdown]
# ## Filtros e Seleções

# %%
fifa[['Overall', 'Potential', 'Value']].head(10)
# Out:
#    Overall  Potential     Value
# 0       94         94  110500.0
# 1       94         94   77000.0
# 2       92         93  118500.0
# 3       91         93   72000.0
# 4       91         92  102000.0
# 5       91         91   93000.0
# 6       91         91   67000.0
# 7       91         91   80000.0
# 8       91         91   51000.0
# 9       90         93   68000.0
