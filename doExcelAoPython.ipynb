# %%
import pandas as pd

train = pd.read_csv('data/tested.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# ## Soma, Contagem, Média

# %%
train.Survived.mean()
# 36% dos passgeiros sobreviveram
# Out:
# 0.36363636363636365

# %%
train.Survived.sum()
# Out:
# 152

# %%
train.shape
# Out:
# (418, 12)

# %%
train.Age.mean()
# Out:
# 30.272590361445783

# %%
train.Age.median()
# Out:
# 27.0

# %%
train.Survived.count()
# Out:
# 418

# %% [markdown]
# ### Contagem condicional

# %%
# Filtro por condição, verdadeiro nesse caso
train[train['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
# Conta quem não sobreviveu
train[train['Survived']==0]['Survived'].count()
# Out:
# 266

# %% [markdown]
# ## Filtros

# %%
# filtra sobreviventes
train[train['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
train.query('Age > 50').head()
# Out:
#     PassengerId  Survived  Pclass  \
# 2           894         0       2
# 13          905         0       2
# 20          912         0       1
# 48          940         1       1
# 69          961         1       1
#
#                                                Name     Sex   Age  SibSp  \
# 2                         Myles, Mr. Thomas Francis    male  62.0      0
# 13                             Howard, Mr. Benjamin    male  63.0      1
# 20                           Rothschild, Mr. Martin    male  55.0      1
# 48  Bucknell, Mrs. William Robert (Emma Eliza Ward)  female  60.0      0
# 69              Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
#
#     Parch    Ticket      Fare        Cabin Embarked
# 2       0    240276    9.6875          NaN        Q
# 13      0     24065   26.0000          NaN        S
# 20      0  PC 17603   59.4000          NaN        C
# 48      0     11813   76.2917          D15        C
# 69      4     19950  263.0000  C23 C25 C27        S

# %%
train.query('Age < 30 & Survived == 1').head()
# Out:
#     PassengerId  Survived  Pclass  \
# 4           896         1       3
# 8           900         1       3
# 12          904         1       1
# 15          907         1       2
# 18          910         1       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# 12  Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1      0
# 15  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1      0
# 18                   Ilmakangas, Miss. Ida Livija  female  27.0      1      0
#
#               Ticket     Fare Cabin Embarked
# 4            3101298  12.2875   NaN        S
# 8               2657   7.2292   NaN        C
# 12             21228  82.2667   B45        S
# 15     SC/PARIS 2167  27.7208   NaN        C
# 18  STON/O2. 3101270   7.9250   NaN        S

# %%
train[(train['Survived']==1) & (train['Sex']=='female')].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 4           896         1       3
# 6           898         1       3
# 8           900         1       3
# 12          904         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 6                            Connolly, Miss. Kate  female  30.0      0      0
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# 12  Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1      0
#
#      Ticket     Fare Cabin Embarked
# 1    363272   7.0000   NaN        S
# 4   3101298  12.2875   NaN        S
# 6    330972   7.6292   NaN        Q
# 8      2657   7.2292   NaN        C
# 12    21228  82.2667   B45        S

# %%
cadastro = train[['PassengerId', 'Survived']]
cadastro.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %% [markdown]
# ## ifelse
